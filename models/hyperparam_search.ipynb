# %%
import pandas as pd 
import numpy as np 

import cupy as cp
import xgboost

import optuna
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import f1_score, make_scorer

# %%
model_dat = pd.read_csv(r'C:\Users\jcmar\my_files\SportsBetting\data\ufc_train_data.csv')


model_cols = ['control_pr_red', 'control_pr_blue',
                'td_pr_red','td_pr_blue', 
                'red_td_accuracy','blue_td_accuracy',
                'red_td_defense','blue_td_defense',
                'sub_att_pr_red','sub_att_pr_blue',

                'red_kd_total', 'blue_kd_total',
                'sigstrikes_pm_red','sigstrikes_pm_blue',
                'red_sigstrike_accuracy','blue_sigstrike_accuracy',
                'red_sigstrike_defense','blue_sigstrike_defense',
                
                'sigstrikes_pm_red', 'sigstrikes_pm_blue',
                'leg_strikes_pm_red','leg_strikes_pm_blue',
                'body_strikes_pm_red', 'body_strikes_pm_blue',
                'head_strikes_pm_red','head_strikes_pm_blue',
                'clinch_strikes_pm_red', 'clinch_strikes_pm_blue',
                'ground_strikes_pm_red', 'ground_strikes_pm_blue',
                'sigstrikes_absorbed_pm_red','sigstrikes_absorbed_pm_blue',

                'reach_diff', 'age_diff',
                'reach_red','reach_blue','weight_class',
                'height_red', 'height_blue', 
                'red_age', 'blue_age', 
                
                'red_elo','blue_elo', 'elo_diff',
                'math_red','math_blue',

                'red_win_streak','blue_win_streak',
                'red_lose_streak','blue_lose_streak',
                'ko_wins_red','ko_wins_blue',
                'sub_wins_red','sub_wins_blue',
                'decision_wins_blue','decision_wins_red',

                'winner', 'red_fighter','blue_fighter',
                'event_country']

xgb_dat = model_dat[model_cols]

le = LabelEncoder()
xgb_dat['event_country'] = le.fit_transform(xgb_dat['event_country'])
xgb_dat['weight_class'] = le.fit_transform(xgb_dat['weight_class'])

mm_scaler = MinMaxScaler()
cat_cols = xgb_dat.select_dtypes(include=['object', 'category']).columns.tolist()
num_categorical = xgb_dat.select_dtypes(include=['object']).shape[1]
print(f"Number of categorical columns: {num_categorical}")
numerical_cols = xgb_dat.columns.difference(cat_cols)
mm_scaler = MinMaxScaler()
xgb_dat[numerical_cols] = mm_scaler.fit_transform(xgb_dat[numerical_cols])

train_len = int(model_dat.shape[0] * .95)
train_dat = xgb_dat[:train_len]
test_dat = xgb_dat[train_len:]

X_train = train_dat.drop(columns=['winner','red_fighter','blue_fighter'])
y_train = train_dat['winner']

X_test = test_dat.drop(columns=['winner','red_fighter','blue_fighter'])
y_test= test_dat['winner']

print(X_train.shape, X_test.shape)
# Out:
# Number of categorical columns: 2
# (5293, 57) (279, 57)
# C:\Users\jcmar\AppData\Local\Temp\ipykernel_11556\3760597229.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xgb_dat['event_country'] = le.fit_transform(xgb_dat['event_country'])
# C:\Users\jcmar\AppData\Local\Temp\ipykernel_11556\3760597229.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xgb_dat['weight_class'] = le.fit_transform(xgb_dat['weight_class'])
# C:\Users\jcmar\AppData\Local\Temp\ipykernel_11556\3760597229.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xgb_dat[numerical_cols] = mm_scaler.fit_transform(xgb_dat[numerical_cols])

# %%
X_train = cp.array(X_train)
X_test = np.array(X_test)
scale_pos_weight = len(y_train[y_train == 0]) / len(y_train[y_train == 1])

def objective(trial):
    param = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'reg_lambda': trial.suggest_float('lambda', 1e-8, 10.0, log=True),  # fixed name
        'reg_alpha': trial.suggest_float('alpha', 1e-8, 10.0, log=True),    # fixed name
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 0.0, 5.0),  # ← pruning regularization
        'device': 'cuda',  # Enables GPU usage
        'scale_pos_weight': scale_pos_weight
    }


    model = xgboost.XGBClassifier(**param)

    # 5-fold CV AUC
    cv = StratifiedKFold(n_splits=15, shuffle=True, random_state=42)

    f1_scorer = make_scorer(f1_score, average='macro')  # Use macro-average to consider both classes equally
    f1_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring=f1_scorer)

    # Return the negative F1 score (since Optuna minimizes the objective function)
    return 1 - f1_scores.mean()

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

print("Best trial:")
trial = study.best_trial
print("  F1: ", 1 - trial.value)
print("  Params: ", trial.params)
# Out:
# [I 2025-04-13 16:01:21,354] A new study created in memory with name: no-name-cd32dc9e-cf41-4e31-93b2-cceab71b9ba4
# [I 2025-04-13 16:01:26,474] Trial 0 finished with value: 0.3926615081608261 and parameters: {'lambda': 5.94241286646472e-07, 'alpha': 9.318203144846235, 'colsample_bytree': 0.5554805360753654, 'subsample': 0.7794680264447966, 'learning_rate': 0.23269786553993302, 'max_depth': 6, 'n_estimators': 516, 'min_child_weight': 8, 'gamma': 2.9811535434667604}. Best is trial 0 with value: 0.3926615081608261.
# [I 2025-04-13 16:01:34,940] Trial 1 finished with value: 0.40865085088460573 and parameters: {'lambda': 0.02366786334011244, 'alpha': 3.45182509942453e-08, 'colsample_bytree': 0.5676702530340847, 'subsample': 0.5513344353539894, 'learning_rate': 0.21977756335238263, 'max_depth': 10, 'n_estimators': 757, 'min_child_weight': 2, 'gamma': 4.25948727121033}. Best is trial 0 with value: 0.3926615081608261.
# [I 2025-04-13 16:01:39,178] Trial 2 finished with value: 0.39137458256040714 and parameters: {'lambda': 0.04063431367183679, 'alpha': 1.0295317413033863e-05, 'colsample_bytree': 0.8955778470023604, 'subsample': 0.6667687416034416, 'learning_rate': 0.10095548101273039, 'max_depth': 4, 'n_estimators': 288, 'min_child_weight': 10, 'gamma': 3.6003414437274204}. Best is trial 2 with value: 0.39137458256040714.
# [I 2025-04-13 16:01:41,532] Trial 3 finished with value: 0.40177309630938274 and parameters: {'lambda': 0.22350184855041338, 'alpha': 0.701032442284183, 'colsample_bytree': 0.4460541737672876, 'subsample': 0.6401228258418844, 'learning_rate': 0.27211653465511587, 'max_depth': 3, 'n_estimators': 154, 'min_child_weight': 2, 'gamma': 3.0329414423660057}. Best is trial 2 with value: 0.39137458256040714.
# [I 2025-04-13 16:01:56,663] Trial 4 finished with value: 0.4163134246281358 and parameters: {'lambda': 0.18666246896989871, 'alpha': 0.000192553934824364, 'colsample_bytree': 0.4694777704065576, 'subsample': 0.7375448432836783, 'learning_rate': 0.23209409298806796, 'max_depth': 6, 'n_estimators': 539, 'min_child_weight': 4, 'gamma': 0.07912888569479637}. Best is trial 2 with value: 0.39137458256040714.
# [I 2025-04-13 16:02:03,515] Trial 5 finished with value: 0.39282437365320055 and parameters: {'lambda': 0.0003340585451368623, 'alpha': 0.01701592033932984, 'colsample_bytree': 0.5447380849694249, 'subsample': 0.9291676114971719, 'learning_rate': 0.12932605449205226, 'max_depth': 3, 'n_estimators': 427, 'min_child_weight': 7, 'gamma': 0.5990125022926146}. Best is trial 2 with value: 0.39137458256040714.
# [I 2025-04-13 16:02:12,367] Trial 6 finished with value: 0.4107363247593909 and parameters: {'lambda': 5.7555135102662005, 'alpha': 0.000267753374336591, 'colsample_bytree': 0.7459511762870741, 'subsample': 0.5188854933854469, 'learning_rate': 0.25334602047253924, 'max_depth': 9, 'n_estimators': 537, 'min_child_weight': 6, 'gamma': 2.4553486296799996}. Best is trial 2 with value: 0.39137458256040714.
# [I 2025-04-13 16:02:27,276] Trial 7 finished with value: 0.41403176463493907 and parameters: {'lambda': 8.078533396639779e-07, 'alpha': 4.2413836955092293e-07, 'colsample_bytree': 0.970043019852083, 'subsample': 0.5663616154821969, 'learning_rate': 0.1911526595136798, 'max_depth': 9, 'n_estimators': 678, 'min_child_weight': 8, 'gamma': 0.8579154505451014}. Best is trial 2 with value: 0.39137458256040714.
# [I 2025-04-13 16:02:33,202] Trial 8 finished with value: 0.414333627873006 and parameters: {'lambda': 0.13650383222860737, 'alpha': 3.21953334997714e-07, 'colsample_bytree': 0.5426744759016633, 'subsample': 0.5142115366751805, 'learning_rate': 0.2388477990062047, 'max_depth': 10, 'n_estimators': 454, 'min_child_weight': 2, 'gamma': 3.494719308828687}. Best is trial 2 with value: 0.39137458256040714.
# [I 2025-04-13 16:02:46,066] Trial 9 finished with value: 0.39264674951015377 and parameters: {'lambda': 0.0007288791312179411, 'alpha': 0.0544311102318583, 'colsample_bytree': 0.7767011361594636, 'subsample': 0.6653208332956335, 'learning_rate': 0.037688229209293475, 'max_depth': 8, 'n_estimators': 781, 'min_child_weight': 1, 'gamma': 2.54248193822139}. Best is trial 2 with value: 0.39137458256040714.
# [I 2025-04-13 16:02:48,523] Trial 10 finished with value: 0.39991026498712634 and parameters: {'lambda': 2.211255878684629e-08, 'alpha': 1.713708149619208e-05, 'colsample_bytree': 0.9707515395600889, 'subsample': 0.8900390191977141, 'learning_rate': 0.09610278137222411, 'max_depth': 5, 'n_estimators': 188, 'min_child_weight': 10, 'gamma': 4.870310609617021}. Best is trial 2 with value: 0.39137458256040714.
# [I 2025-04-13 16:03:05,357] Trial 11 finished with value: 0.39559846839296375 and parameters: {'lambda': 0.0005329925598953065, 'alpha': 0.0810084279645068, 'colsample_bytree': 0.8179259312755351, 'subsample': 0.6964599377340993, 'learning_rate': 0.03854327266571399, 'max_depth': 8, 'n_estimators': 898, 'min_child_weight': 4, 'gamma': 1.8463198957437923}. Best is trial 2 with value: 0.39137458256040714.
# [I 2025-04-13 16:03:23,836] Trial 12 finished with value: 0.38887921071784814 and parameters: {'lambda': 0.0037924633775031774, 'alpha': 0.0051898579277361535, 'colsample_bytree': 0.8677533453668338, 'subsample': 0.8146488585759382, 'learning_rate': 0.011980019743294028, 'max_depth': 4, 'n_estimators': 977, 'min_child_weight': 10, 'gamma': 1.9981776645491294}. Best is trial 12 with value: 0.38887921071784814.
# [I 2025-04-13 16:03:30,201] Trial 13 finished with value: 0.3917522490924499 and parameters: {'lambda': 0.008017341746867506, 'alpha': 1.0117131851949575e-05, 'colsample_bytree': 0.8711511831766978, 'subsample': 0.8172937789321684, 'learning_rate': 0.011850595543156102, 'max_depth': 4, 'n_estimators': 329, 'min_child_weight': 10, 'gamma': 1.5682820368586132}. Best is trial 12 with value: 0.38887921071784814.
# [I 2025-04-13 16:03:38,938] Trial 14 finished with value: 0.39727378428637883 and parameters: {'lambda': 1.4415407159575402e-05, 'alpha': 0.009425772578532218, 'colsample_bytree': 0.8779750030326878, 'subsample': 0.8522721746449979, 'learning_rate': 0.09028855638196408, 'max_depth': 4, 'n_estimators': 963, 'min_child_weight': 9, 'gamma': 3.799424202523263}. Best is trial 12 with value: 0.38887921071784814.
# [I 2025-04-13 16:03:45,607] Trial 15 finished with value: 0.39817706859919366 and parameters: {'lambda': 7.723521366974846, 'alpha': 1.1922103104988432e-05, 'colsample_bytree': 0.6725199264618542, 'subsample': 0.6166774945600134, 'learning_rate': 0.08631974440286191, 'max_depth': 5, 'n_estimators': 289, 'min_child_weight': 10, 'gamma': 1.7207194488727138}. Best is trial 12 with value: 0.38887921071784814.
# [I 2025-04-13 16:03:51,261] Trial 16 finished with value: 0.39445129772807574 and parameters: {'lambda': 0.006153431731761115, 'alpha': 0.0022482229598809154, 'colsample_bytree': 0.8981154749369612, 'subsample': 0.986141344550707, 'learning_rate': 0.15976216159861392, 'max_depth': 4, 'n_estimators': 660, 'min_child_weight': 8, 'gamma': 4.245464384571243}. Best is trial 12 with value: 0.38887921071784814.
# [I 2025-04-13 16:03:57,328] Trial 17 finished with value: 0.38924608236815816 and parameters: {'lambda': 1.71293197297103e-05, 'alpha': 0.0011034817453629444, 'colsample_bytree': 0.6399833470990007, 'subsample': 0.7352356725785485, 'learning_rate': 0.06048259400326311, 'max_depth': 5, 'n_estimators': 299, 'min_child_weight': 6, 'gamma': 2.23631846722239}. Best is trial 12 with value: 0.38887921071784814.
# [I 2025-04-13 16:04:01,551] Trial 18 finished with value: 0.3866736902833512 and parameters: {'lambda': 1.728329869682076e-05, 'alpha': 0.0019051552016897877, 'colsample_bytree': 0.66909441326383, 'subsample': 0.7366289434142865, 'learning_rate': 0.048312133144648856, 'max_depth': 7, 'n_estimators': 119, 'min_child_weight': 5, 'gamma': 1.2130374454559754}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:04:05,871] Trial 19 finished with value: 0.3891088172480892 and parameters: {'lambda': 2.096711869315808e-05, 'alpha': 0.17717254030580193, 'colsample_bytree': 0.720194565722129, 'subsample': 0.7981848605718208, 'learning_rate': 0.020255204891893946, 'max_depth': 7, 'n_estimators': 106, 'min_child_weight': 4, 'gamma': 1.1571894388848067}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:04:35,004] Trial 20 finished with value: 0.40095616824338287 and parameters: {'lambda': 1.1568168150023367e-06, 'alpha': 0.6296184673554576, 'colsample_bytree': 0.6212152150379019, 'subsample': 0.8819655709480851, 'learning_rate': 0.059140515356090814, 'max_depth': 7, 'n_estimators': 985, 'min_child_weight': 5, 'gamma': 0.14595502627055645}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:04:40,275] Trial 21 finished with value: 0.3882636582379617 and parameters: {'lambda': 1.7325854673649156e-05, 'alpha': 0.32748339666723775, 'colsample_bytree': 0.7184377790750072, 'subsample': 0.7977489137677842, 'learning_rate': 0.017299599330079102, 'max_depth': 7, 'n_estimators': 138, 'min_child_weight': 4, 'gamma': 1.0391147417524178}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:04:48,196] Trial 22 finished with value: 0.39143538718403925 and parameters: {'lambda': 0.000130384031625231, 'alpha': 7.197385070750858, 'colsample_bytree': 0.8065368128958289, 'subsample': 0.8359103616367078, 'learning_rate': 0.010239413243866756, 'max_depth': 7, 'n_estimators': 227, 'min_child_weight': 5, 'gamma': 1.1649621727371624}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:04:52,891] Trial 23 finished with value: 0.3979871006261956 and parameters: {'lambda': 4.215054190686092e-06, 'alpha': 0.002990337727653666, 'colsample_bytree': 0.6737980726127515, 'subsample': 0.7641952588201639, 'learning_rate': 0.058015705029499626, 'max_depth': 8, 'n_estimators': 106, 'min_child_weight': 3, 'gamma': 1.3535470191551158}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:05:04,833] Trial 24 finished with value: 0.3956831810689696 and parameters: {'lambda': 1.901864821536015e-07, 'alpha': 9.580246397883829e-05, 'colsample_bytree': 0.737418342684743, 'subsample': 0.7138520278193603, 'learning_rate': 0.045764014412051385, 'max_depth': 6, 'n_estimators': 420, 'min_child_weight': 7, 'gamma': 0.6348606646366857}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:05:15,190] Trial 25 finished with value: 0.39775114617287843 and parameters: {'lambda': 0.0017827489813621563, 'alpha': 1.4291711347415248, 'colsample_bytree': 0.8272866428047858, 'subsample': 0.9298305485310535, 'learning_rate': 0.11994832441013935, 'max_depth': 7, 'n_estimators': 880, 'min_child_weight': 3, 'gamma': 0.805640861076826}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:05:24,391] Trial 26 finished with value: 0.3976573680526092 and parameters: {'lambda': 0.00017036198545331688, 'alpha': 0.01329216223790538, 'colsample_bytree': 0.6156680689731155, 'subsample': 0.7701788338521913, 'learning_rate': 0.07186674850089093, 'max_depth': 6, 'n_estimators': 636, 'min_child_weight': 5, 'gamma': 2.0363753655731354}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:05:35,305] Trial 27 finished with value: 0.3888621970852538 and parameters: {'lambda': 7.655694299092138e-05, 'alpha': 0.1641373877187067, 'colsample_bytree': 0.6653070773511636, 'subsample': 0.8609317917737144, 'learning_rate': 0.029698289555381518, 'max_depth': 8, 'n_estimators': 360, 'min_child_weight': 6, 'gamma': 1.5469022908306782}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:05:40,096] Trial 28 finished with value: 0.4016718178226869 and parameters: {'lambda': 4.7151576904123075e-05, 'alpha': 0.178909941816835, 'colsample_bytree': 0.6732136773174202, 'subsample': 0.870852823353965, 'learning_rate': 0.15205191592671305, 'max_depth': 9, 'n_estimators': 225, 'min_child_weight': 6, 'gamma': 1.394149880026664}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:05:46,153] Trial 29 finished with value: 0.4104981161314475 and parameters: {'lambda': 2.4902005252222335e-06, 'alpha': 4.655065788422043, 'colsample_bytree': 0.5801546519662962, 'subsample': 0.9159148684742509, 'learning_rate': 0.29736468741072586, 'max_depth': 8, 'n_estimators': 355, 'min_child_weight': 7, 'gamma': 0.342230926419113}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:05:53,218] Trial 30 finished with value: 0.39500383763416413 and parameters: {'lambda': 9.926084551815084e-08, 'alpha': 0.06374985515027484, 'colsample_bytree': 0.5105965967264472, 'subsample': 0.9757964915220165, 'learning_rate': 0.03723716272279751, 'max_depth': 8, 'n_estimators': 174, 'min_child_weight': 3, 'gamma': 0.9903013326423271}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:06:01,639] Trial 31 finished with value: 0.38786755415668794 and parameters: {'lambda': 8.356069174437312e-05, 'alpha': 0.007834202869850806, 'colsample_bytree': 0.7070958379364864, 'subsample': 0.7974742430208958, 'learning_rate': 0.02572791299119928, 'max_depth': 6, 'n_estimators': 374, 'min_child_weight': 4, 'gamma': 2.6855021139470363}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:06:10,072] Trial 32 finished with value: 0.38759793314913904 and parameters: {'lambda': 6.70303073365505e-05, 'alpha': 0.0006075911705277245, 'colsample_bytree': 0.7000584033109613, 'subsample': 0.7782562880196522, 'learning_rate': 0.0286862449005267, 'max_depth': 7, 'n_estimators': 375, 'min_child_weight': 4, 'gamma': 2.804393393477734}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:06:14,547] Trial 33 finished with value: 0.39167777083272537 and parameters: {'lambda': 4.861033222500592e-06, 'alpha': 0.0009544846249556426, 'colsample_bytree': 0.7088553157083262, 'subsample': 0.7755238663054884, 'learning_rate': 0.06580282627719283, 'max_depth': 7, 'n_estimators': 235, 'min_child_weight': 4, 'gamma': 2.9389772258940807}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:06:21,421] Trial 34 finished with value: 0.3974334089855366 and parameters: {'lambda': 4.1351831946998906e-05, 'alpha': 8.971235240279577e-05, 'colsample_bytree': 0.7693438262181646, 'subsample': 0.6993944565601702, 'learning_rate': 0.07699421788914729, 'max_depth': 6, 'n_estimators': 465, 'min_child_weight': 3, 'gamma': 2.8643093829266597}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:06:26,000] Trial 35 finished with value: 0.38801548171149136 and parameters: {'lambda': 9.38829080508107e-06, 'alpha': 0.0006856378685492864, 'colsample_bytree': 0.4058914159858804, 'subsample': 0.7962448903440591, 'learning_rate': 0.11543559088405035, 'max_depth': 5, 'n_estimators': 394, 'min_child_weight': 5, 'gamma': 3.362032978220419}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:06:31,004] Trial 36 finished with value: 0.4010262731209334 and parameters: {'lambda': 4.379729840216274e-06, 'alpha': 0.0010975428149049375, 'colsample_bytree': 0.47665659532830956, 'subsample': 0.7422477949615455, 'learning_rate': 0.11179665443675421, 'max_depth': 5, 'n_estimators': 401, 'min_child_weight': 5, 'gamma': 3.346971931598461}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:06:37,634] Trial 37 finished with value: 0.39392566472433 and parameters: {'lambda': 1.3685144788959846e-07, 'alpha': 4.0475612961442144e-05, 'colsample_bytree': 0.415788234417348, 'subsample': 0.7182998113920293, 'learning_rate': 0.13424757856513408, 'max_depth': 5, 'n_estimators': 592, 'min_child_weight': 5, 'gamma': 3.2172668545649}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:06:43,668] Trial 38 finished with value: 0.4041610157832458 and parameters: {'lambda': 0.0016073507634291712, 'alpha': 0.00042715777107947686, 'colsample_bytree': 0.5830861136105191, 'subsample': 0.6736455272142153, 'learning_rate': 0.19976162065247438, 'max_depth': 6, 'n_estimators': 499, 'min_child_weight': 4, 'gamma': 2.6690779672768117}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:06:49,191] Trial 39 finished with value: 0.3976546033487123 and parameters: {'lambda': 0.00021110383382149154, 'alpha': 1.3784121836609072e-06, 'colsample_bytree': 0.40827647083016677, 'subsample': 0.7520430954490556, 'learning_rate': 0.052012667818699836, 'max_depth': 6, 'n_estimators': 373, 'min_child_weight': 3, 'gamma': 3.8389109949992424}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:06:56,822] Trial 40 finished with value: 0.4027124711080575 and parameters: {'lambda': 5.296600054738166e-07, 'alpha': 0.028414688217786796, 'colsample_bytree': 0.5113519570818439, 'subsample': 0.6176759478509211, 'learning_rate': 0.10705561171659017, 'max_depth': 6, 'n_estimators': 502, 'min_child_weight': 2, 'gamma': 2.352599820291646}. Best is trial 18 with value: 0.3866736902833512.
# [I 2025-04-13 16:07:01,833] Trial 41 finished with value: 0.38327454569839026 and parameters: {'lambda': 1.5262358086850977e-05, 'alpha': 0.00034206783207601854, 'colsample_bytree': 0.7665222121861451, 'subsample': 0.8031603263616118, 'learning_rate': 0.027262028250113212, 'max_depth': 7, 'n_estimators': 145, 'min_child_weight': 4, 'gamma': 2.842434862624574}. Best is trial 41 with value: 0.38327454569839026.
# [I 2025-04-13 16:07:09,381] Trial 42 finished with value: 0.3859263743189678 and parameters: {'lambda': 7.070905238691132e-06, 'alpha': 0.00035036913679344057, 'colsample_bytree': 0.7666920307766752, 'subsample': 0.8262393666349229, 'learning_rate': 0.026354080824763843, 'max_depth': 7, 'n_estimators': 260, 'min_child_weight': 5, 'gamma': 2.696529121505159}. Best is trial 41 with value: 0.38327454569839026.
# [I 2025-04-13 16:07:16,148] Trial 43 finished with value: 0.39118970361037 and parameters: {'lambda': 5.8321083268849226e-05, 'alpha': 0.00014748097506446387, 'colsample_bytree': 0.7702004446187658, 'subsample': 0.8330990467841208, 'learning_rate': 0.02982315472205847, 'max_depth': 7, 'n_estimators': 259, 'min_child_weight': 4, 'gamma': 2.6929729047078577}. Best is trial 41 with value: 0.38327454569839026.
# [I 2025-04-13 16:07:20,433] Trial 44 finished with value: 0.38350488839267416 and parameters: {'lambda': 2.1314548242055002e-06, 'alpha': 0.00421787615054028, 'colsample_bytree': 0.7501718255587757, 'subsample': 0.8318599035357169, 'learning_rate': 0.04647589197516007, 'max_depth': 7, 'n_estimators': 183, 'min_child_weight': 6, 'gamma': 3.076374946060141}. Best is trial 41 with value: 0.38327454569839026.
# [I 2025-04-13 16:07:24,746] Trial 45 finished with value: 0.39025673361998847 and parameters: {'lambda': 4.6510933498509697e-07, 'alpha': 0.00030821986770709924, 'colsample_bytree': 0.7943936996430778, 'subsample': 0.8355408157588611, 'learning_rate': 0.04635353218521346, 'max_depth': 9, 'n_estimators': 183, 'min_child_weight': 6, 'gamma': 3.7159240103203817}. Best is trial 41 with value: 0.38327454569839026.
# [I 2025-04-13 16:07:28,215] Trial 46 finished with value: 0.39838996448465747 and parameters: {'lambda': 1.8162337653984865e-06, 'alpha': 4.053830352099313e-05, 'colsample_bytree': 0.8371164422766433, 'subsample': 0.8937614479867375, 'learning_rate': 0.07937386633144666, 'max_depth': 7, 'n_estimators': 142, 'min_child_weight': 7, 'gamma': 2.1785206027765778}. Best is trial 41 with value: 0.38327454569839026.
# [I 2025-04-13 16:07:33,519] Trial 47 finished with value: 0.3861954297058059 and parameters: {'lambda': 2.328137180936313e-08, 'alpha': 3.456950124525361e-06, 'colsample_bytree': 0.7563645804172083, 'subsample': 0.8204077567741848, 'learning_rate': 0.04030750460526637, 'max_depth': 8, 'n_estimators': 210, 'min_child_weight': 6, 'gamma': 3.0870398702544115}. Best is trial 41 with value: 0.38327454569839026.
# [I 2025-04-13 16:07:38,622] Trial 48 finished with value: 0.39054808435662713 and parameters: {'lambda': 4.2946364801607e-08, 'alpha': 2.137664517563848e-08, 'colsample_bytree': 0.7525362797276345, 'subsample': 0.8181664447806012, 'learning_rate': 0.04219157583400206, 'max_depth': 8, 'n_estimators': 200, 'min_child_weight': 6, 'gamma': 3.0516441752503467}. Best is trial 41 with value: 0.38327454569839026.
# [I 2025-04-13 16:07:42,156] Trial 49 finished with value: 0.398380052706397 and parameters: {'lambda': 1.0408730801441818e-08, 'alpha': 2.809290345053389e-06, 'colsample_bytree': 0.9209900380135946, 'subsample': 0.8544236214671869, 'learning_rate': 0.09257243900471944, 'max_depth': 10, 'n_estimators': 257, 'min_child_weight': 8, 'gamma': 4.21144181424737}. Best is trial 41 with value: 0.38327454569839026.
# Best trial:
#   F1:  0.6167254543016097
#   Params:  {'lambda': 1.5262358086850977e-05, 'alpha': 0.00034206783207601854, 'colsample_bytree': 0.7665222121861451, 'subsample': 0.8031603263616118, 'learning_rate': 0.027262028250113212, 'max_depth': 7, 'n_estimators': 145, 'min_child_weight': 4, 'gamma': 2.842434862624574}

# %%
import pandas as pd

# %%
fp = r'C:\Users\jcmar\my_files\SportsBetting\data\training_data\entire_odds_stats_2026-03-07.csv'
df_model = pd.read_csv(fp)

# %%
df_model.info(verbose=True, max_cols=None)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8112 entries, 0 to 8111
# Data columns (total 297 columns):
#  #    Column                                Dtype
# ---   ------                                -----
#  0    td_defense_pct_red                    float64
#  1    td_total_attempted_against_red        float64
#  2    td_total_landed_against_red           float64
#  3    td_defense_pct_blue                   float64
#  4    td_total_attempted_against_blue       float64
#  5    td_total_landed_against_blue          float64
#  6    sig_str_defense_pct_red               float64
#  7    sig_str_total_attempted_against_red   float64
#  8    sig_str_total_landed_against_red      float64
#  9    sig_str_defense_pct_blue              float64
#  10   sig_str_total_attempted_against_blue  float64
#  11   sig_str_total_landed_against_blue     float64
#  12   td_accuracy_pct_red                   float64
#  13   td_accuracy_pct_blue                  float64
#  14   sig_str_accuracy_pct_red              float64
#  15   sig_str_accuracy_pct_blue             float64
#  16   kd_pm_red                             float64
#  17   kd_total_red                          float64
#  18   kd_pm_blue                            float64
#  19   kd_total_blue                         float64
#  20   sig_str_landed_pm_red                 float64
#  21   sig_str_landed_total_red              float64
#  22   sig_str_landed_pm_blue                float64
#  23   sig_str_landed_total_blue             float64
#  24   sig_str_absorbed_pm_red               float64
#  25   sig_str_absorbed_total_red            float64
#  26   sig_str_absorbed_pm_blue              float64
#  27   sig_str_absorbed_total_blue           float64
#  28   sig_str_attempted_pm_red              float64
#  29   sig_str_attempted_total_red           float64
#  30   sig_str_attempted_pm_blue             float64
#  31   sig_str_attempted_total_blue          float64
#  32   leg_str_pm_red                        float64
#  33   leg_str_total_red                     float64
#  34   leg_str_pm_blue                       float64
#  35   leg_str_total_blue                    float64
#  36   head_str_pm_red                       float64
#  37   head_str_total_red                    float64
#  38   head_str_pm_blue                      float64
#  39   head_str_total_blue                   float64
#  40   body_str_pm_red                       float64
#  41   body_str_total_red                    float64
#  42   body_str_pm_blue                      float64
#  43   body_str_total_blue                   float64
#  44   clinch_str_pm_red                     float64
#  45   clinch_str_total_red                  float64
#  46   clinch_str_pm_blue                    float64
#  47   clinch_str_total_blue                 float64
#  48   td_landed_pm_red                      float64
#  49   td_landed_total_red                   float64
#  50   td_landed_pm_blue                     float64
#  51   td_landed_total_blue                  float64
#  52   td_attempted_pm_red                   float64
#  53   td_attempted_total_red                float64
#  54   td_attempted_pm_blue                  float64
#  55   td_attempted_total_blue               float64
#  56   td_defended_pm_red                    float64
#  57   td_defended_total_red                 float64
#  58   td_defended_pm_blue                   float64
#  59   td_defended_total_blue                float64
#  60   control_pm_red                        float64
#  61   control_total_red                     float64
#  62   control_pm_blue                       float64
#  63   control_total_blue                    float64
#  64   sub_att_pm_red                        float64
#  65   sub_att_total_red                     float64
#  66   sub_att_pm_blue                       float64
#  67   sub_att_total_blue                    float64
#  68   reverse_pm_red                        float64
#  69   reverse_total_red                     float64
#  70   reverse_pm_blue                       float64
#  71   reverse_total_blue                    float64
#  72   total_fight_time_red                  float64
#  73   total_fight_time_blue                 float64
#  74   age_red                               float64
#  75   age_blue                              float64
#  76   height_red                            float64
#  77   height_blue                           float64
#  78   reach_red                             float64
#  79   reach_blue                            float64
#  80   date                                  str
#  81   event_location                        str
#  82   weight_class                          str
#  83   title_fight                           float64
#  84   performance_bonus_winner              float64
#  85   fight_otn_bonus                       float64
#  86   method                                str
#  87   winner                                float64
#  88   winner_name                           str
#  89   ratio_td_red                          float64
#  90   ratio_td_blue                         float64
#  91   ratio_control_red                     float64
#  92   ratio_control_blue                    float64
#  93   ratio_sig_str_red                     float64
#  94   ratio_sig_str_blue                    float64
#  95   adjusted_sig_str_red                  float64
#  96   adjusted_sig_str_blue                 float64
#  97   adjusted_td_red                       float64
#  98   adjusted_td_blue                      float64
#  99   ratio_td_diff                         float64
#  100  ratio_control_diff                    float64
#  101  ratio_sigstrike_diff                  float64
#  102  kd_total_diff                         float64
#  103  kd_pm_diff                            float64
#  104  sig_str_landed_total_diff             float64
#  105  sig_str_landed_pm_diff                float64
#  106  sig_str_absorbed_total_diff           float64
#  107  sig_str_absorbed_pm_diff              float64
#  108  sig_str_attempted_total_diff          float64
#  109  sig_str_attempted_pm_diff             float64
#  110  leg_str_total_diff                    float64
#  111  leg_str_pm_diff                       float64
#  112  head_str_total_diff                   float64
#  113  head_str_pm_diff                      float64
#  114  body_str_total_diff                   float64
#  115  body_str_pm_diff                      float64
#  116  clinch_str_total_diff                 float64
#  117  clinch_str_pm_diff                    float64
#  118  td_landed_total_diff                  float64
#  119  td_landed_pm_diff                     float64
#  120  td_attempted_total_diff               float64
#  121  td_attempted_pm_diff                  float64
#  122  control_total_diff                    float64
#  123  control_pm_diff                       float64
#  124  sub_att_total_diff                    float64
#  125  sub_att_pm_diff                       float64
#  126  reverse_total_diff                    float64
#  127  reverse_pm_diff                       float64
#  128  age_diff                              float64
#  129  height_diff                           float64
#  130  reach_diff                            float64
#  131  sig_str_defense_pct_diff              float64
#  132  sig_str_accuracy_pct_diff             float64
#  133  td_accuracy_pct_diff                  float64
#  134  td_defense_pct_diff                   float64
#  135  opp_age_red                           float64
#  136  opp_age_blue                          float64
#  137  opp_reach_red                         float64
#  138  opp_reach_blue                        float64
#  139  avg_fight_min_red                     float64
#  140  avg_fight_min_blue                    float64
#  141  avg_fight_min_diff                    float64
#  142  total_bonus_red                       float64
#  143  total_bonus_blue                      float64
#  144  total_bonus_diff                      float64
#  145  elo_red                               float64
#  146  elo_blue                              float64
#  147  elo_red_proba                         float64
#  148  elo_blue_proba                        float64
#  149  elo_diff                              float64
#  150  elo_pred                              int64
#  151  glicko_red                            float64
#  152  glicko_blue                           float64
#  153  glicko_rd_red                         float64
#  154  glicko_rd_blue                        float64
#  155  glicko_proba_red                      float64
#  156  glicko_proba_blue                     float64
#  157  glicko_diff                           float64
#  158  glicko_pred                           int64
#  159  rating_agree                          int64
#  160  math_red                              int64
#  161  math_blue                             int64
#  162  months_since_red                      float64
#  163  months_since_blue                     float64
#  164  months_since_diff                     float64
#  165  win_streak_red                        float64
#  166  lose_streak_red                       float64
#  167  win_streak_blue                       float64
#  168  lose_streak_blue                      float64
#  169  win_pct_red                           float64
#  170  win_pct_blue                          float64
#  171  num_fights_red                        float64
#  172  num_fights_blue                       float64
#  173  num_wins_red                          float64
#  174  num_wins_blue                         float64
#  175  num_losses_red                        float64
#  176  num_losses_blue                       float64
#  177  num_fights_diff                       float64
#  178  win_streak_diff                       float64
#  179  lose_streak_diff                      float64
#  180  wins_diff                             float64
#  181  losses_diff                           float64
#  182  win_pct_diff                          float64
#  183  decision_wins_red                     int64
#  184  ko_wins_red                           int64
#  185  sub_wins_red                          int64
#  186  decision_wins_blue                    int64
#  187  ko_wins_blue                          int64
#  188  sub_wins_blue                         int64
#  189  decision_wins_diff                    int64
#  190  ko_wins_diff                          int64
#  191  sub_wins_diff                         int64
#  192  decision_losses_red                   int64
#  193  ko_losses_red                         int64
#  194  sub_losses_red                        int64
#  195  decision_losses_blue                  int64
#  196  ko_losses_blue                        int64
#  197  sub_losses_blue                       int64
#  198  decision_losses_diff                  int64
#  199  ko_losses_diff                        int64
#  200  sub_losses_diff                       int64
#  201  ko_pct_red                            float64
#  202  dec_pct_red                           float64
#  203  sub_pct_red                           float64
#  204  ko_pct_blue                           float64
#  205  dec_pct_blue                          float64
#  206  sub_pct_blue                          float64
#  207  ko_pct_diff                           float64
#  208  dec_pct_diff                          float64
#  209  sub_pct_diff                          float64
#  210  womens_fight                          int64
#  211  red_title_fights                      float64
#  212  blue_title_fights                     float64
#  213  red_title_wins                        float64
#  214  blue_title_wins                       float64
#  215  red_title_losses                      float64
#  216  blue_title_losses                     float64
#  217  red_title_win_pct                     float64
#  218  blue_title_win_pct                    float64
#  219  event_age                             int64
#  220  fighter_red                           str
#  221  fighter_blue                          str
#  222  red_fighter_stats                     str
#  223  blue_fighter_stats                    str
#  224  open_blue                             float64
#  225  close1_blue                           float64
#  226  close2_blue                           float64
#  227  open_red                              float64
#  228  close1_red                            float64
#  229  close2_red                            float64
#  230  event_date                            str
#  231  og_blue_name                          str
#  232  og_red_fighter                        str
#  233  dec_open_red                          float64
#  234  dec_close1_red                        float64
#  235  dec_close2_red                        float64
#  236  dec_open_blue                         float64
#  237  dec_close1_blue                       float64
#  238  dec_close2_blue                       float64
#  239  dec_fair_open_red                     float64
#  240  dec_fair_open_blue                    float64
#  241  proba_fair_open_red                   float64
#  242  proba_fair_open_blue                  float64
#  243  pimp_open_red                         float64
#  244  pimp_open_blue                        float64
#  245  dec_fair_close1_red                   float64
#  246  dec_fair_close1_blue                  float64
#  247  proba_fair_close1_red                 float64
#  248  proba_fair_close1_blue                float64
#  249  pimp_close1_red                       float64
#  250  pimp_close1_blue                      float64
#  251  dec_fair_close2_red                   float64
#  252  dec_fair_close2_blue                  float64
#  253  proba_fair_close2_red                 float64
#  254  proba_fair_close2_blue                float64
#  255  pimp_close2_red                       float64
#  256  pimp_close2_blue                      float64
#  257  juice_open_red                        float64
#  258  juice_close1_red                      float64
#  259  juice_close2_red                      float64
#  260  juice_open_blue                       float64
#  261  juice_close1_blue                     float64
#  262  juice_close2_blue                     float64
#  263  vegas_acc_open                        float64
#  264  vegas_acc_close1                      float64
#  265  vegas_acc_close2                      float64
#  266  proba_fair_open_diff                  float64
#  267  proba_fair_close1_diff                float64
#  268  proba_fair_close2_diff                float64
#  269  line_movement_close1_red              float64
#  270  line_movement_close1_blue             float64
#  271  line_movement_close2_red              float64
#  272  line_movement_close2_blue             float64
#  273  red_ud_to_fav_close1                  object
#  274  red_ud_to_fav_close2                  object
#  275  red_stayed_fav_close1                 object
#  276  red_stayed_fav_close2                 object
#  277  red_fav_to_ud_close1                  object
#  278  red_fav_to_ud_close2                  object
#  279  red_stayed_dog_close1                 object
#  280  red_stayed_dog_close2                 object
#  281  blue_ud_to_fav_close1                 float64
#  282  blue_ud_to_fav_close2                 float64
#  283  blue_stayed_fav_close1                float64
#  284  blue_stayed_fav_close2                float64
#  285  blue_fav_to_ud_close1                 float64
#  286  blue_fav_to_ud_close2                 float64
#  287  blue_stayed_dog_close1                float64
#  288  blue_stayed_dog_close2                float64
#  289  red_fighter_odds                      str
#  290  blue_fighter_odds                     str
#  291  fav_counts_red                        int64
#  292  dog_counts_red                        int64
#  293  fav_counts_blue                       int64
#  294  dog_counts_blue                       int64
#  295  fav_counts_diff                       int64
#  296  dog_counts_diff                       int64
# dtypes: float64(244), int64(31), object(8), str(14)
# memory usage: 19.6+ MB

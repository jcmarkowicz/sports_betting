# %%
from langchain.document_loaders.web import WebBaseLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.embeddings import DeepSeekEmbeddings
from langchain.chains import RetrievalQA
from langchain.llms import DeepSeek
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain.document_loaders.web import WebBaseLoader
#       2 from langchain.text_splitter import RecursiveCharacterTextSplitter
#       3 from langchain.vectorstores import FAISS
#
# ModuleNotFoundError: No module named 'langchain.document_loaders'

# %%
# 1. Load documents from URLs
urls = ["https://example.com/article1", "https://example.com/article2"]
loader = WebBaseLoader(urls)
docs = loader.load()

# 2. Split text into chunks
splitter = RecursiveCharacterTextSplitter(chunk_size=800, chunk_overlap=50)
chunks = splitter.split_documents(docs)

# 3. Create embeddings (DeepSeek embeddings)
embeddings = DeepSeekEmbeddings()
vectorstore = FAISS.from_documents(chunks, embeddings)

# 4. Build a retrieval-based QA chain
retriever = vectorstore.as_retriever()
llm = DeepSeek(model_name="DeepSeek-V3")  # Local GPU model
qa = RetrievalQA(llm=llm, retriever=retriever)

# 5. Ask a question
query = "Summarize the main points from these pages."
answer = qa.run(query)
print(answer)

# %%
pip install "langchain[docs]"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: langchain 1.0.7 does not provide the extra 'docs'
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
